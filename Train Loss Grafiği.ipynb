# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
val_loss = [0.000246, 0.000154, 0.000184, 0.000069, 0.000115, 0.000088, 0.000067, 0.000038, 0.000107, 0.000059, 0.000027,0.000053, 0.000079, 0.000046, 0.000046, 0.000044, 0.000072, 0.000032]
loss = [0.0001, 0.000078, 0.000052, 0.000062, 0.000038, 0.000043,0.000043,  0.000037, 0.000049, 0.000054, 0.000024, 0.000039, 0.000028, 0.000042, 0.000027, 0.000027, 0.000028, 0.000039]
val_mae = [0.005507, 0.005979, 0.005012, 0.003120, 0.002505, 0.003729, 0.012652, 0.005065, 0.009623, 0.002174, 0.002203, 0.002506, 0.006478, 0.002510, 0.002471, 0.002919, 0.007763, 0.004659]
mae = [0.006494, 0.006935, 0.004357, 0.005157, 0.002966, 0.004309, 0.003677, 0.003781, 0.003484, 0.004243, 0.002242, 0.003263, 0.002882, 0.003910, 0.002636, 0.002783, 0.002388, 0.002854]
val_mse = [0.000242, 0.000150, 0.000151, 0.000051, 0.000075, 0.000057, 0.000191, 0.000048, 0.000136, 0.000043, 0.000018, 0.000037, 0.000099, 0.000030, 0.000028, 0.000031, 0.000092, 0.000037]
mse = [0.000170, 0.000142, 0.000075, 0.000087, 0.000037, 0.000053, 0.000050, 0.000044, 0.000047, 0.000059, 0.000019, 0.000035, 0.000027, 0.000050, 0.000023, 0.000022, 0.000022, 0.000031]

# %%
x = [i for i in range(1, 19)]  # X values (18 elements)
y1 = loss  # Replace with actual loss data
y2 = val_loss  # Replace with actual validation loss data

# Create the plot
plt.figure(figsize=(10, 6))

# Plotting the first line
plt.plot(x, y1, label="Kayıp", color="b", linestyle='-', marker='s', markersize=8, linewidth=2)

# Plotting the second line
plt.plot(x, y2, label="Doğrulama_Kayıp", color="r", linestyle='-', marker='s', markersize=8, linewidth=2)

# Adding title and labels
plt.title("Eğitim Kayıp Fonksiyonu Grafiği", fontsize=16, fontweight='bold')
plt.xlabel("Dönem", fontsize=14)  # Changed to Turkish (Epoch)
plt.ylabel("Kayıp Değeri", fontsize=14)  # Changed to Turkish (Loss Value)

# Customizing the grid
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.7)

# Adding a legend
plt.legend(loc="upper left", fontsize=12)

# Customizing the tick parameters
plt.xticks(range(1, 19), fontsize=12)  # Set x-ticks to integers 1 through 18
plt.yticks(fontsize=12)

# Setting the y-axis to scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("C:\\Users\\hp\\Desktop\\Loss.png", dpi = 300)
# Displaying the plot
plt.tight_layout()
plt.show()

# %%
x = [i for i in range(1, 19)]  # X values (18 elements)
y1 = mae  # Replace with actual loss data
y2 = val_mae  # Replace with actual validation loss data

# Create the plot
plt.figure(figsize=(10, 6))

# Plotting the first line
plt.plot(x, y1, label="MAE", color="b", linestyle='-', marker='s', markersize=8, linewidth=2)

# Plotting the second line
plt.plot(x, y2, label="Doğrulama_MAE", color="r", linestyle='-', marker='s', markersize=8, linewidth=2)

# Adding title and labels
plt.title("Eğitim MAE Fonksiyonu Grafiği", fontsize=16, fontweight='bold')
plt.xlabel("Dönem", fontsize=14)  # Changed to Turkish (Epoch)
plt.ylabel("MAE Değeri", fontsize=14)  # Changed to Turkish (Loss Value)

# Customizing the grid
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.7)

# Adding a legend
plt.legend(loc="upper left", fontsize=12)

# Customizing the tick parameters
plt.xticks(range(1, 19), fontsize=12)  # Set x-ticks to integers 1 through 18
plt.yticks(fontsize=12)

# Setting the y-axis to scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("C:\\Users\\hp\\Desktop\\MAE.png", dpi = 300)
# Displaying the plot
plt.tight_layout()
plt.show()

# %%
x = [i for i in range(1, 19)]  # X values (18 elements)
y1 = mse  # Replace with actual loss data
y2 = val_mse  # Replace with actual validation loss data

# Create the plot
plt.figure(figsize=(10, 6))

# Plotting the first line
plt.plot(x, y1, label="MSE", color="b", linestyle='-', marker='s', markersize=8, linewidth=2)

# Plotting the second line
plt.plot(x, y2, label="Doğrulama_MSE", color="r", linestyle='-', marker='s', markersize=8, linewidth=2)

# Adding title and labels
plt.title("Eğitim MSE Fonksiyonu Grafiği", fontsize=16, fontweight='bold')
plt.xlabel("Dönem", fontsize=14)  # Changed to Turkish (Epoch)
plt.ylabel("MSE Değeri", fontsize=14)  # Changed to Turkish (Loss Value)

# Customizing the grid
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.7)

# Adding a legend
plt.legend(loc="upper left", fontsize=12)

# Customizing the tick parameters
plt.xticks(range(1, 19), fontsize=12)  # Set x-ticks to integers 1 through 18
plt.yticks(fontsize=12)

# Setting the y-axis to scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("C:\\Users\\hp\\Desktop\\MSE.png", dpi = 300)
# Displaying the plot
plt.tight_layout()
plt.show()
