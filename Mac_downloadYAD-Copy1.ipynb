# %%
pip install astropy
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: /opt/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install astroquery
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: /opt/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from astropy.table import Table
from astroquery.mast import Observations

# %%
table = Table.read("mac_download.txt", format = "ascii")
table
# Out:
# <Table length=3341>
#   obsID   obs_collection dataproduct_type ... dataRights calib_level filters
#   int64        str3            str5       ...    str6       int64     str13
# --------- -------------- ---------------- ... ---------- ----------- -------
# 207496152            HST            image ...     PUBLIC           3   F439W
# 207496152            HST            image ...     PUBLIC           3   F439W
# 207496152            HST            image ...     PUBLIC           3   F439W
# 207496152            HST            image ...     PUBLIC           3   F439W
# 207496152            HST            image ...     PUBLIC           3   F439W
# 207496152            HST            image ...     PUBLIC           3   F439W
#       ...            ...              ... ...        ...         ...     ...
# 207473889            HST            image ...     PUBLIC           3   F606W
# 207473889            HST            image ...     PUBLIC           3   F606W
# ...

# %%
Observations.download_products(products=table, flat=True, download_dir="//Users//user2//Desktop//2204AYAD")
# Out:
# INFO: 1896 of 3341 products were duplicates. Only downloading 1445 unique product(s). [astroquery.mast.observations]
# INFO: Found cached file //Users//user2//Desktop//2204AYAD/hst_10082_y8_wfpc2_pc_f606w_u8uoy8_drz.fits with expected size 243967680. [astroquery.query]
# INFO: Found cached file //Users//user2//Desktop//2204AYAD/hst_10082_y9_wfpc2_pc_f606w_u8uoy9_drz.fits with expected size 243967680. [astroquery.query]
# INFO: Found cached file //Users//user2//Desktop//2204AYAD/hst_10082_ya_wfpc2_pc_f606w_u8uoya_drz.fits with expected size 243967680. [astroquery.query]
# INFO: Found cached file //Users//user2//Desktop//2204AYAD/hst_10082_yb_wfpc2_pc_f606w_u8uoyb_drz.fits with expected size 244347840. [astroquery.query]
# INFO: Found cached file //Users//user2//Desktop//2204AYAD/hst_10082_yc_wfpc2_pc_f606w_u8uoyc_drz.fits with expected size 243967680. [astroquery.query]
# ...
