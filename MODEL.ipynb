# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (2.12.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.53.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.9)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.8)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.44.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\programdata\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install tensorflow-datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.9.3-py3-none-any.whl (5.0 MB)
#      ---------------------------------------- 5.0/5.0 MB 230.7 kB/s eta 0:00:00
# Requirement already satisfied: toml in c:\programdata\anaconda3\lib\site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: numpy in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (1.23.5)
# Requirement already satisfied: absl-py in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (1.4.0)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp39-cp39-win_amd64.whl (101 kB)
#      -------------------------------------- 101.5/101.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.20 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (3.20.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (2.32.3)
# Collecting etils[enp,epath,etree]>=0.9.0
#   Downloading etils-1.5.2-py3-none-any.whl (140 kB)
#      -------------------------------------- 140.6/140.6 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from tensorflow-datasets) (8.0.4)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.16.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: termcolor in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (2.3.0)
# Requirement already satisfied: tqdm in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from tensorflow-datasets) (4.66.5)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from tensorflow-datasets) (1.14.1)
# Collecting array-record
#   Downloading array_record-0.4.1-py39-none-any.whl (3.0 MB)
#      ---------------------------------------- 3.0/3.0 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from tensorflow-datasets) (5.9.0)
# Requirement already satisfied: importlib_resources in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (6.4.5)
# Requirement already satisfied: typing_extensions in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (4.12.2)
# Requirement already satisfied: zipp in c:\programdata\anaconda3\lib\site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (3.8.0)
# Requirement already satisfied: fsspec in c:\users\kullanıcı\appdata\roaming\python\python39\site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (1.26.11)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->tensorflow-datasets) (0.4.5)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from promise->tensorflow-datasets) (1.16.0)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21544 sha256=281c8237a14c9a19f2e85dc9e64cf117880707b5cce33f8d2e54da9ae0ce70d2
#   Stored in directory: c:\users\kullanıcı\appdata\local\pip\cache\wheels\e1\e8\83\ddea66100678d139b14bc87692ece57c6a2a937956d2532608
# Successfully built promise
# Installing collected packages: dm-tree, tensorflow-metadata, promise, etils, array-record, tensorflow-datasets
# Successfully installed array-record-0.4.1 dm-tree-0.1.8 etils-1.5.2 promise-2.3 tensorflow-datasets-4.9.3 tensorflow-metadata-1.16.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model

# %%
def conv_block(x,num_filters):
  x=L.Conv2D(num_filters,3, padding="same")(x)
  x=L.BatchNormalization()(x)
  x=L.Activation("relu")(x)

  x=L.Conv2D(num_filters,3, padding="same")(x)
  x=L.BatchNormalization()(x)
  x=L.Activation("relu")(x)

  x=L.Conv2D(num_filters,3, padding="same")(x)
  x=L.BatchNormalization()(x)
  x=L.Activation("relu")(x)

  x=L.Conv2D(num_filters, 3, padding="same")(x)
  x=L.BatchNormalization()(x)
  x=L.Activation("relu")(x)
  return x

# %%
def encoder_block(x, num_filters):
  X=conv_block(x, num_filters)
  p=L.MaxPool2D((2,2))(X)
  return X, p

# %%
def attention_gate(g, s, num_filters):
  Wg=L.Conv2D(num_filters, 1, padding="same")(s)
  Wg=L.BatchNormalization()(Wg)

  Ws=L.Conv2D(num_filters, 1, padding="same")(s)
  Ws= L.BatchNormalization()(Ws)

  out=L.Activation("relu")(Wg+Ws)
  out=L.Conv2D(num_filters, 1, padding="same")(out)
  out=L.Activation("sigmoid")(out)

  return out*s

# %%
def decoder_block(x,s,num_filters):
  x=L.UpSampling2D(interpolation="bilinear")(x)
  s= attention_gate(x,s,num_filters)
  x = L.Concatenate()([x,s])
  x=conv_block(x,num_filters)
  return x

# %%
def attention_unet(input_shape):
    
    input_=L.Input(input_shape)
    

    s1, p1 = encoder_block(input_,64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3= encoder_block(p2,256)
    s4, p4= encoder_block(p3, 256)

    b1=conv_block(p4,512)

    d1=decoder_block(b1,s4, 256)
    d2=decoder_block(d1,s3,256)
    d3=decoder_block(d2,s2, 128)
    d4=decoder_block(d3,s1, 64)
    

    outputs=L.Conv2D(1,1,padding="same", activation="relu")(d4)

    model=Model(input_, outputs, name="Attention- Unet")
    return model

# %%
if __name__=="__main__":
  input_shape=(512,512,3)
  model= attention_unet(input_shape)
  model.summary()
# Out:
# Model: "Attention- Unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 64  36928       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 64  36928       ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 512, 512, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 12  147584      ['activation_5[0][0]']
#                                 8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  activation_6 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_6[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 12  147584      ['activation_6[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_7[0][0]']
#  rmalization)                   8)
#
#  activation_7 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_7[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_7[0][0]']
#                                 8)
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_8[0][0]']
#  rmalization)                   6)
#
#  activation_8 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 25  590080      ['activation_8[0][0]']
#                                 6)
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_9[0][0]']
#  rmalization)                   6)
#
#  activation_9 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_9[0][0]']
#                                 6)
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 25  590080      ['activation_9[0][0]']
#                                 6)
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 25  1024       ['conv2d_10[0][0]']
#  ormalization)                  6)
#
#  activation_10 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_10[0][0]']
#                                 6)
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 25  590080      ['activation_10[0][0]']
#                                 6)
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 25  1024       ['conv2d_11[0][0]']
#  ormalization)                  6)
#
#  activation_11 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_11[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  590080      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_15[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_17[0][0]']
#  conv2d_18 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 256)  65792       ['activation_15[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 256)  65792       ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_18[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 64, 64, 256)  0          ['batch_normalization_20[0][0]',
#  da)                                                              'batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 64, 64, 256)  0           ['tf.__operators__.add[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 256)  65792       ['activation_20[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 256)  0           ['conv2d_22[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 512)  0           ['activation_19[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 64, 64, 256)  0           ['activation_21[0][0]',
#                                                                   'activation_15[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_23[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 25  65792       ['activation_11[0][0]']
#                                 6)
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 25  65792       ['activation_11[0][0]']
#                                 6)
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 25  1024       ['conv2d_27[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 25  1024       ['conv2d_28[0][0]']
#  ormalization)                  6)
#
#  activation_24 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_24[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 128, 128, 25  0          ['batch_normalization_26[0][0]',
#  mbda)                          6)                                'batch_normalization_27[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 128, 128, 25  0           ['tf.__operators__.add_1[0][0]']
#                                 6)
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 25  65792       ['activation_26[0][0]']
#                                 6)
#
#  activation_25 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 128, 128, 25  0           ['conv2d_29[0][0]']
#                                 6)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_25[0][0]']
#                                 6)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 128, 128, 25  0          ['activation_27[0][0]',
#  )                              6)                                'activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['up_sampling2d_1[0][0]',
#                                 2)                                'tf.math.multiply_1[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 25  1024       ['conv2d_30[0][0]']
#  ormalization)                  6)
#
#  activation_28 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_28[0][0]']
#                                 6)
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 25  590080      ['activation_28[0][0]']
#                                 6)
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 25  1024       ['conv2d_31[0][0]']
#  ormalization)                  6)
#
#  activation_29 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_29[0][0]']
#                                 6)
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 25  590080      ['activation_29[0][0]']
#                                 6)
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  16512       ['activation_7[0][0]']
#                                 8)
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 12  16512       ['activation_7[0][0]']
#                                 8)
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 25  1024       ['conv2d_32[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  activation_30 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_30[0][0]']
#                                 6)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 256, 256, 12  0          ['batch_normalization_32[0][0]',
#  mbda)                          8)                                'batch_normalization_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 25  590080      ['activation_30[0][0]']
#                                 6)
#
#  activation_32 (Activation)     (None, 256, 256, 12  0           ['tf.__operators__.add_2[0][0]']
#                                 8)
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 25  1024       ['conv2d_33[0][0]']
#  ormalization)                  6)
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 12  16512       ['activation_32[0][0]']
#                                 8)
#
#  activation_31 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_31[0][0]']
#                                 6)
#
#  activation_33 (Activation)     (None, 256, 256, 12  0           ['conv2d_36[0][0]']
#                                 8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 25  0          ['activation_31[0][0]']
#                                 6)
#
#  tf.math.multiply_2 (TFOpLambda  (None, 256, 256, 12  0          ['activation_33[0][0]',
#  )                              8)                                'activation_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_2[0][0]',
#                                 4)                                'tf.math.multiply_2[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 12  512        ['conv2d_37[0][0]']
#  ormalization)                  8)
#
#  activation_34 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_34[0][0]']
#                                 8)
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 12  147584      ['activation_34[0][0]']
#                                 8)
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 12  512        ['conv2d_38[0][0]']
#  ormalization)                  8)
#
#  activation_35 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_35[0][0]']
#                                 8)
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 12  147584      ['activation_35[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 512, 512, 64  4160        ['activation_3[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 512, 512, 64  4160        ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 12  512        ['conv2d_39[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_38 (BatchN  (None, 512, 512, 64  256        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  batch_normalization_39 (BatchN  (None, 512, 512, 64  256        ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_36[0][0]']
#                                 8)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 512, 512, 64  0          ['batch_normalization_38[0][0]',
#  mbda)                          )                                 'batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 12  147584      ['activation_36[0][0]']
#                                 8)
#
#  activation_38 (Activation)     (None, 512, 512, 64  0           ['tf.__operators__.add_3[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 256, 256, 12  512        ['conv2d_40[0][0]']
#  ormalization)                  8)
#
#  conv2d_43 (Conv2D)             (None, 512, 512, 64  4160        ['activation_38[0][0]']
#                                 )
#
#  activation_37 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_37[0][0]']
#                                 8)
#
#  activation_39 (Activation)     (None, 512, 512, 64  0           ['conv2d_43[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 12  0          ['activation_37[0][0]']
#                                 8)
#
#  tf.math.multiply_3 (TFOpLambda  (None, 512, 512, 64  0          ['activation_39[0][0]',
#  )                              )                                 'activation_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'tf.math.multiply_3[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 512, 512, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_40 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_40[0][0]']
#                                 )
#  conv2d_45 (Conv2D)             (None, 512, 512, 64  36928       ['activation_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 512, 512, 64  256        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 512, 512, 64  36928       ['activation_41[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 512, 512, 64  256        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 512, 512, 64  36928       ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 512, 512, 64  256        ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 512, 512, 1)  65          ['activation_43[0][0]']
#
# ==================================================================================================
# Total params: 21,404,481
# Trainable params: 21,386,305
# Non-trainable params: 18,176
# __________________________________________________________________________________________________
