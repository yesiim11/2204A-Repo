# %%
from astroquery.mast import Observations
from astropy.table import Table

# %%
table = Table.read("C:\\Users\\hp\\Desktop\\04A\\deniz_download.txt", format="ascii")
# Out:
# WARNING: OverflowError converting to IntType in column size, reverting to String. [astropy.io.ascii.fastbasic]

# %%
Observations.download_products(products = table, download_dir= "F:\\YAD", flat=True)
# Out:
# INFO: 1853 of 3100 products were duplicates. Only downloading 1247 unique product(s). [astroquery.mast.observations]
# INFO: Found cached file F:\YAD\hst_10082_jr_wfpc2_pc_f606w_u8uojr_drz.fits with expected size 269092800. [astroquery.query]
# INFO: Found cached file F:\YAD\hst_10082_vj_wfpc2_pc_f606w_u8uovj_drz.fits with expected size 220858560. [astroquery.query]
# INFO: Found cached file F:\YAD\hst_10082_vk_wfpc2_pc_f606w_u8uovk_drz.fits with expected size 221572800. [astroquery.query]
# INFO: Found cached file F:\YAD\hst_10082_vl_wfpc2_pc_f606w_u8uovl_drz.fits with expected size 220855680. [astroquery.query]
# INFO: Found cached file F:\YAD\hst_10084_b4_wfpc2_pc_f450w_u8w8b4_drz.fits with expected size 219744000. [astroquery.query]
# INFO: Found cached file F:\YAD\hst_10084_b4_wfpc2_pc_f606w_u8w8b4_drz.fits with expected size 219732480. [astroquery.query]
# ...
